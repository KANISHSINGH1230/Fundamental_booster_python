# %%
print("Welcome to the interactive personal Data collector!")


name = str(input( "enetr your name ="))
age = int(input(" enetr your age ="))
height = float(input(" enetr your height in meters ="))
favourite = int(input(" enetr your favourite number ="))


print(" Thank you! Here is the information we collected:")


print("name:",name,"(type :", type(name),"memory Address :", id(name),")")
print("age:",age,"(type :",type(age),"memory Address :",id(age),")")
print("height",height,"(type :",type(height),"memory Address :",id(height),")")
print("favourite",favourite,"(type :",type(favourite),"memory Address :",id(favourite),")")


print("your year is approximately:", 2025 - age,("base on your age of",age))


print("Thank yor for using the personal Data collector. Goodbye!")
# Out:
# Welcome to the interactive personal Data collector!
# enetr your name =kanish
#  enetr your age =21
#  enetr your height in meters =23.2
#  enetr your favourite number =12
#  Thank you! Here is the information we collected:
# name: kanish (type : <class 'str'> memory Address : 132150714775712 )
# age: 21 (type : <class 'int'> memory Address : 11645992 )
# height 23.2 (type : <class 'float'> memory Address : 132150714889008 )
# favourite 12 (type : <class 'int'> memory Address : 11645704 )
# your year is approximately: 2004 ('base on your age of', 21)
# Thank yor for using the personal Data collector. Goodbye!
